# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./drive-download-20240126T132517Z-001/supplementary_tables/boiler_engine_emission_factors.csv')

# %%
df = df[df['fuel_category'] == 2]
print("Boiler Engine")
df
# Out:
# Boiler Engine
#           fuel  fuel_category sulfur  n_ox      pm10  pm2_5     voc   sox  \
# 1  Global 2020              2  0.50%   2.0  0.352686   0.32  0.1053  2.83
#
#     n2_O    ch4  bsfc
# 1  0.049  0.002   290

# %%
df_propulsion = pd.read_csv('drive-download-20240126T132517Z-001\supplementary_tables\propulsion_engine_emission_factors.csv')
df_propulsion = df_propulsion[df_propulsion['fuel_category'] == 2]
print("propulsion engine emission factors")
df_propulsion
# Out:
# propulsion engine emission factors
#            fuel  fuel_category sulfur engine_type  emission_tier model_years  \
# 6   Global 2020              2  0.50%         SSD              0    Pre-2000
# 7   Global 2020              2  0.50%         SSD              1   2000-2010
# 8   Global 2020              2  0.50%         SSD              2   post 2010
# 9   Global 2020              2  0.50%         MSD              0    Pre-2000
# 10  Global 2020              2  0.50%         MSD              1   2000-2010
# 11  Global 2020              2  0.50%         MSD              2   post 2010
#
#      nox  pm10  pm2_5    voc    sox   n2_O   ch4  bsfc
# 6   17.0  0.31   0.28  0.632  1.808  0.034  0.01   185
# 7   16.0  0.31   0.28  0.632  1.808  0.034  0.01   185
# 8   14.4  0.31   0.28  0.632  1.808  0.034  0.01   185
# 9   13.2  0.31   0.29  0.530  1.984  0.030  0.01   203
# 10  12.2  0.31   0.29  0.530  1.984  0.030  0.01   203
# 11  10.5  0.31   0.29  0.530  1.984  0.030  0.01   203

# %%
df_aux = pd.read_csv('drive-download-20240126T132517Z-001/supplementary_tables/auxiliary_engine_emission_factors.csv')
df_aux = df_aux[df_aux['fuel_category'] == 2]
print("Auxileray")
df_aux
# Out:
# Auxileray
#            fuel  fuel_category sulfur engine_size  emission_tier model_years  \
# 6   Global 2020              2  0.50%    < 800 kW              0    Pre-2000
# 7   Global 2020              2  0.50%    < 800 kW              1   2000-2010
# 8   Global 2020              2  0.50%    < 800 kW              2   post 2010
# 9   Global 2020              2  0.50%    > 800 kW              0    Pre-2000
# 10  Global 2020              2  0.50%    > 800 kW              1   2000-2010
# 11  Global 2020              2  0.50%    > 800 kW              2   post 2010
#
#      nox  pm10  pm2_5    voc  s_ox   n2_o   ch4  bsfc
# 6   13.8  0.32   0.29  0.421  2.14  0.036  0.01   219
# 7   12.2  0.32   0.29  0.421  2.14  0.036  0.01   219
# 8   10.5  0.32   0.29  0.421  2.14  0.036  0.01   219
# 9   13.8  0.32   0.30  0.421  2.23  0.036  0.01   228
# 10  12.2  0.32   0.30  0.421  2.23  0.036  0.01   228
# 11  10.5  0.32   0.30  0.421  2.23  0.036  0.01   228

# %%
df = pd.read_csv('./dataset/vessel_movements_MBCC.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4296\635381859.py:1: DtypeWarning: Columns (19,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./dataset/vessel_movements_MBCC.csv')

# %%
df['berth'].unique()
# Out:
# array([nan, 'MBCC Berth 2', 'MBCC Berth 1'], dtype=object)

# %%
df2 = df[df['speed'] < 1]

# %%
df2['coverage'].unique()
# Out:
# array(['MBCC Limit'], dtype=object)

# %%
df['operating_mode'] = "Anchorage"
df.loc[((df['speed'] > 1) | (df['nav_stat'].isin([0, 3, 4, 8, 11, 12]))) & (df['maneuvering_zone'] == 'MBCC Maneouvering Zone'), 'operating_mode'] = "Maneuvering"
df.loc[(df['speed'] < 1) & (pd.notna(df['berth'])), 'operating_mode'] = "Alongside"
df.loc[((df['speed'] > 1) | (df['nav_stat'].isin([0, 3, 4, 8, 11, 12]))) & (df['maneuvering_zone'] != 'MBCC Maneouvering Zone'), 'operating_mode'] = "Transit"

# Filter rows where operating_mode is 'Alongside'
alongside_df = df[df['operating_mode'] == 'Alongside']

# %%
df
# Out:
#              imo       mmsi  vessel_id    vessel_name date_of_build  \
# 0        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 1        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 2        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 3        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 4        9117739  477878000     842992     SAGA MONAL    1996-12-01
# ...          ...        ...        ...            ...           ...
# 1226299  9420801  244155000     770779    DELTAGRACHT    2009-05-01
# 1226300  8616568  259753000     686819  SEAWAY OSPREY    1989-07-01
# 1226301  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226302  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226303  9385817  351943000     674244       ABOUDI D    2007-10-01
#
#                                   vessel_type          group  \
# 0        Heavy Load Carrier, semi submersible  General Cargo
# ...

# %%
df3 = df[df['operating_mode'] == 'Transit']

# %%
df10 = df[df['sfc_ab'] != 0]
df10
# Out:
#              imo       mmsi  vessel_id    vessel_name date_of_build  \
# 0        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 1        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 2        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 3        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 4        9117739  477878000     842992     SAGA MONAL    1996-12-01
# ...          ...        ...        ...            ...           ...
# 1226299  9420801  244155000     770779    DELTAGRACHT    2009-05-01
# 1226300  8616568  259753000     686819  SEAWAY OSPREY    1989-07-01
# 1226301  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226302  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226303  9385817  351943000     674244       ABOUDI D    2007-10-01
#
#                                   vessel_type          group  \
# 0        Heavy Load Carrier, semi submersible  General Cargo
# ...

# %%
df.fillna(0, inplace=True)

# %%
df2 = df[df['sfc_ae'] == 0]
df2
# Out:
#              imo       mmsi  vessel_id  vessel_name date_of_build  \
# 0        9808223  414272000     754519  ZHEN HUA 33    2017-03-01
# 1        9808223  414272000     754519  ZHEN HUA 33    2017-03-01
# 2        9808223  414272000     754519  ZHEN HUA 33    2017-03-01
# 3        9808223  414272000     754519  ZHEN HUA 33    2017-03-01
# 25178    8623248  525023095     687395     SEAFLYTE    1981-01-01
# ...          ...        ...        ...          ...           ...
# 1223334  9484223  305546000     751312   BBC NAPLES    2010-06-01
# 1223335  9484223  305546000     751312   BBC NAPLES    2010-06-01
# 1223336  9484223  305546000     751312   BBC NAPLES    2010-06-01
# 1223337  9484223  305546000     751312   BBC NAPLES    2010-06-01
# 1223338  9484223  305546000     751312   BBC NAPLES    2010-06-01
#
#                                   vessel_type             group  \
# 0        Heavy Load Carrier, semi submersible     General Cargo
# ...

# %%
df2['operating_mode'].unique()
# Out:
# array(['Transit', 'Anchorage'], dtype=object)

# %%
df3 = df[df['sfc_ae'] != 0]
df3
# Out:
#              imo       mmsi  vessel_id    vessel_name date_of_build  \
# 4        9117739  477878000     842992     SAGA MONAL    1996-12-01
# 5        9117739  477878000     842992     SAGA MONAL    1996-12-01
# 6        9117739  477878000     842992     SAGA MONAL    1996-12-01
# 7        9117739  477878000     842992     SAGA MONAL    1996-12-01
# 8        9117739  477878000     842992     SAGA MONAL    1996-12-01
# ...          ...        ...        ...            ...           ...
# 1226299  9420801  244155000     770779    DELTAGRACHT    2009-05-01
# 1226300  8616568  259753000     686819  SEAWAY OSPREY    1989-07-01
# 1226301  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226302  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226303  9385817  351943000     674244       ABOUDI D    2007-10-01
#
#                                   vessel_type          group  \
# 4                       Open Hatch Cargo Ship  General Cargo
# ...

# %%
df3['sfc_ab'].unique()
# Out:
# array([300.])

# %%
df
# Out:
#              imo       mmsi  vessel_id    vessel_name date_of_build  \
# 0        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 1        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 2        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 3        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 4        9117739  477878000     842992     SAGA MONAL    1996-12-01
# ...          ...        ...        ...            ...           ...
# 1226299  9420801  244155000     770779    DELTAGRACHT    2009-05-01
# 1226300  8616568  259753000     686819  SEAWAY OSPREY    1989-07-01
# 1226301  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226302  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226303  9385817  351943000     674244       ABOUDI D    2007-10-01
#
#                                   vessel_type          group  \
# 0        Heavy Load Carrier, semi submersible  General Cargo
# ...

# %%
df_Transit = df[df['operating_mode'] == 'Transit']
df_Transit
# Out:
#              imo       mmsi  vessel_id    vessel_name date_of_build  \
# 0        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 1        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 2        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 3        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 4        9117739  477878000     842992     SAGA MONAL    1996-12-01
# ...          ...        ...        ...            ...           ...
# 1226298  9783942  636023123     696317       JAVA SEA    2019-05-01
# 1226299  9420801  244155000     770779    DELTAGRACHT    2009-05-01
# 1226300  8616568  259753000     686819  SEAWAY OSPREY    1989-07-01
# 1226302  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226303  9385817  351943000     674244       ABOUDI D    2007-10-01
#
#                                   vessel_type                    group  \
# 0        Heavy Load Carrier, semi submersible            General Cargo
# ...

# %%
df_Transit_nude = df_Transit[['vref']]
df_Transit_speed = df_Transit[['speed']]

# %%
df_Transit_speed
# Out:
#          speed
# 0          0.0
# 1          5.0
# 2          4.0
# 3          4.0
# 4          0.0
# ...        ...
# 1226298    0.0
# 1226299    0.0
# 1226300    0.0
# 1226302    0.0
# 1226303    0.0
#
# [317872 rows x 1 columns]

# %%
df_Transit_nude.head()
# Out:
#     vref
# 0   0.00
# 1   0.00
# 2   0.00
# 3   0.00
# 4  16.35

# %%
for each in df_Transit_nude:
    df_Transit_nude_maxspeed = df_Transit_nude['vref'] * 1.066

# %%
df_Transit_nude_maxspeed
# Out:
# 0           0.0000
# 1           0.0000
# 2           0.0000
# 3           0.0000
# 4          17.4291
#             ...
# 1226298    15.3504
# 1226299    17.0560
# 1226300    14.9240
# 1226302    13.3250
# 1226303    13.3250
# Name: vref, Length: 317872, dtype: float64

# %%
x = pd.concat([df_Transit_nude_maxspeed,df_Transit_speed], axis=1)
x
# Out:
#             vref  speed
# 0         0.0000    0.0
# 1         0.0000    5.0
# 2         0.0000    4.0
# 3         0.0000    4.0
# 4        17.4291    0.0
# ...          ...    ...
# 1226298  15.3504    0.0
# 1226299  17.0560    0.0
# 1226300  14.9240    0.0
# 1226302  13.3250    0.0
# 1226303  13.3250    0.0
#
# [317872 rows x 2 columns]

# %%
df_Transit['max_speed'] = df_Transit['vref'] * 1.066
df_Transit['load_factor'] = (df_Transit['speed'] / df_Transit['max_speed']) ** 3
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4296\687233924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Transit['max_speed'] = df_Transit['vref'] * 1.066
# C:\Users\user\AppData\Local\Temp\ipykernel_4296\687233924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Transit['load_factor'] = (df_Transit['speed'] / df_Transit['max_speed']) ** 3

# %%
# shwdf = df_Transit[df_Transit['load_factor'] < 0.2]
shwdf = df_Transit[df_Transit['aux_engine_fuel_type'] == 'NOT APPLICABLE']
shwdf
# Out:
#              imo       mmsi  vessel_id     vessel_name date_of_build  \
# 0        9808223  414272000     754519     ZHEN HUA 33    2017-03-01
# 1        9808223  414272000     754519     ZHEN HUA 33    2017-03-01
# 2        9808223  414272000     754519     ZHEN HUA 33    2017-03-01
# 3        9808223  414272000     754519     ZHEN HUA 33    2017-03-01
# 106      9585429  574000270     790359  HAI PHUONG SKY    2010-03-01
# ...          ...        ...        ...             ...           ...
# 1226273  9671888  563451000     828215         ENTHRAL    2013-09-01
# 1226274  9529358  563603000     865674      STAR QUEST    2009-06-01
# 1226275  9675121  563882000     847584      MARLIN DUA    2013-12-01
# 1226279  9698812  565173000     676935    AYER CHERDEK    2014-08-01
# 1226280  9698812  565173000     676935    AYER CHERDEK    2014-08-01
#
#                                   vessel_type                    group  \
# ...

# %%
df_Transit["load_factor"].unique()
# Out:
# array([           nan,            inf, 0.00000000e+00, ...,
#        1.29538599e-04, 8.79279045e-03, 1.58405028e-01])

# %%
df_Transit.dropna()
# Out:
#              imo       mmsi  vessel_id    vessel_name date_of_build  \
# 1        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 2        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 3        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 4        9117739  477878000     842992     SAGA MONAL    1996-12-01
# 5        9117739  477878000     842992     SAGA MONAL    1996-12-01
# ...          ...        ...        ...            ...           ...
# 1226298  9783942  636023123     696317       JAVA SEA    2019-05-01
# 1226299  9420801  244155000     770779    DELTAGRACHT    2009-05-01
# 1226300  8616568  259753000     686819  SEAWAY OSPREY    1989-07-01
# 1226302  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226303  9385817  351943000     674244       ABOUDI D    2007-10-01
#
#                                   vessel_type                    group  \
# 1        Heavy Load Carrier, semi submersible            General Cargo
# ...

# %%
df_Transit_update = df_Transit[df_Transit['load_factor'] != 'inf']
df_Transit_update
# Out:
#              imo       mmsi  vessel_id    vessel_name date_of_build  \
# 0        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 1        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 2        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 3        9808223  414272000     754519    ZHEN HUA 33    2017-03-01
# 4        9117739  477878000     842992     SAGA MONAL    1996-12-01
# ...          ...        ...        ...            ...           ...
# 1226298  9783942  636023123     696317       JAVA SEA    2019-05-01
# 1226299  9420801  244155000     770779    DELTAGRACHT    2009-05-01
# 1226300  8616568  259753000     686819  SEAWAY OSPREY    1989-07-01
# 1226302  9385817  351943000     674244       ABOUDI D    2007-10-01
# 1226303  9385817  351943000     674244       ABOUDI D    2007-10-01
#
#                                   vessel_type                    group  \
# 0        Heavy Load Carrier, semi submersible            General Cargo
# ...
